# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# from datetime import datetime
import datetime
from dateutil.relativedelta import relativedelta


load_dotenv()


hostname=os.getenv("hostname")
database=os.getenv("database")
username=os.getenv("username")
pwd=os.getenv("pwd")
port_id=os.getenv("port_id")
host = os.getenv("host")

import warnings
warnings.filterwarnings('ignore')

# %%
conn_string = f"postgresql://{username}:{pwd}@{host}:{port_id}/{database}"
db =  create_engine(url=conn_string)

transactions = pd.read_sql("SELECT * FROM transactions", db)
historicalPricesAG = pd.read_sql('SELECT * FROM "historical_pricesA_G" ', db)
historicalPricesHR = pd.read_sql('SELECT * FROM "historical_pricesH_R" ', db)
historicalPricesSZ = pd.read_sql('SELECT * FROM "historical_pricesS_Z" ', db)
senators = pd.read_sql("SELECT * FROM senator_info", db)

transactions.head()
# Out:
#   transaction_date   owner ticker      asset_description asset_type  \
# 0       2020-04-14  Spouse    DOW               Dow Inc.      Stock
# 1       2020-04-07   Joint   HELE  Helen of Troy Limited      Stock
# 2       2018-12-06    Self    PFE            Pfizer Inc.      Stock
# 3       2017-09-26  Spouse      T              AT&T Inc.      Stock
# 4       2014-06-19  Spouse     CR       Crane Co. (NYSE)    Unknown
#
#           type             amount comment          senator  \
# 0  Sale (Full)  $15,001 - $50,000      --   Kelly Loeffler
# 1  Sale (Full)  $15,001 - $50,000      --   Kelly Loeffler
# 2  Sale (Full)   $1,001 - $15,000      --     Jerry Moran,
# 3  Sale (Full)   $1,001 - $15,000     sep      Pat Roberts
# 4  Sale (Full)   $1,001 - $15,000      --  Susan M Collins
#
#                                             ptr_link disclosure_date    id  \
# 0  https://efdsearch.senate.gov/search/view/ptr/2...      2020-05-01  2198
# 1  https://efdsearch.senate.gov/search/view/ptr/2...      2020-05-01  2317
# 2  https://efdsearch.senate.gov/search/view/ptr/d...      2019-05-15  3451
# 3  https://efdsearch.senate.gov/search/view/ptr/8...      2017-09-29  5683
# 4  https://efdsearch.senate.gov/search/view/ptr/9...      2014-06-27  9111
#
#    senatorId alpha senator_id
# 0        137  None        137
# 1        137  None        137
# 2        119  None        119
# 3        133  None        133
# 4        106  None        106

# %%
# %store transactions
# %store historicalPricesAG
# %store historicalPricesHR
# %store historicalPricesSZ
# %store senators
# Out:
# Stored 'transactions' (DataFrame)
# Stored 'historicalPricesAG' (DataFrame)
# Stored 'historicalPricesHR' (DataFrame)
# Stored 'historicalPricesSZ' (DataFrame)
# Stored 'senators' (DataFrame)
